# %% [markdown]
# # 20170213_0.0100xxx rol_mean = 7

# %%
from utility import *
# %matplotlib inline
rcParams['figure.figsize'] = 20, 6

# %%
# data = pd.read_csv('../dataPreProcessed/user_pay_countbyday.csv',parse_dates=True)

# %%
data= pd.read_csv('../withWeather1.csv',index_col=0,parse_dates=True)

# %%
data.index = data['日期']

# %%
data[data['商家id']==1].sort_index()
# Out:
#             index          日期   流量  市名  位置编号  人均消费   评分   评论数  门店等级 一级品类名称  \
# 日期
# 2015-10-10      0  2015-10-10  188  湖州   885     8  4.0  12.0     2     美食
# 2015-10-11      1  2015-10-11  272  湖州   885     8  4.0  12.0     2     美食
# 2015-10-12      2  2015-10-12  257  湖州   885     8  4.0  12.0     2     美食
# 2015-10-13      3  2015-10-13  239  湖州   885     8  4.0  12.0     2     美食
# 2015-10-14      4  2015-10-14  277  湖州   885     8  4.0  12.0     2     美食
# 2015-10-15      5  2015-10-15  227  湖州   885     8  4.0  12.0     2     美食
# 2015-10-16      6  2015-10-16  242  湖州   885     8  4.0  12.0     2     美食
# 2015-10-17      7  2015-10-17  293  湖州   885     8  4.0  12.0     2     美食
# 2015-10-18      8  2015-10-18  291  湖州   885     8  4.0  12.0     2     美食
# 2015-10-19      9  2015-10-19  256  湖州   885     8  4.0  12.0     2     美食
# 2015-10-20     10  2015-10-20  262  湖州   885     8  4.0  12.0     2     美食
# ...

# %% [markdown]
# # 参数
#     1.滑窗
#         全部window=3 -》 0.0100xx
#         滑窗的参数,可以根据店家来调整 -》 如何对商家进行分类？
#     2.原序列平稳性分析
#         outlier去除(重新填写均值)
#         取对数 ?
#     3.中位数
#     4. history data select which period?

# %% [markdown]
# # 奇葩, 后三个礼拜依然有空值的商家
# # 1707, 1824 个别处理
#     1707 填10-17~10-24， 10-24后开始没数据
#     1825 填09-01~09-14， 10-10后开始没数据

# %% [markdown]
# # 加入天气、雾霾、节日的影响
